# %%
import numpy as np
import random
def insertion(arr):
    for i in range(0,len(arr)-1):
      print("Outer Loop: ", i)
      if arr[i]>arr[i+1]:
        print(" Swapping Order of outer loop: ", arr[i] ," , ", arr[i+1])
        arr[i],arr[i+1]=arr[i+1],arr[i]
        for j in range(i,0,-1):
          print(" Inner Loop: ", j)
          if arr[j]<arr[j-1]:
            print(" Swapping order of inner loop: ", arr[j]," , " ,arr[j+1])
            arr[j],arr[j-1]=arr[j-1],arr[j]
arr=np.random.randint(1,30,5)
print(arr)
insertion(arr)
print('Sorted Array in Ascending Order:')
print(arr)
# Out:
# [25 21 16 18 29]
# Outer Loop:  0
#  Swapping Order of outer loop:  25  ,  21
# Outer Loop:  1
#  Swapping Order of outer loop:  25  ,  16
#  Inner Loop:  1
#  Swapping order of inner loop:  16  ,  25
# Outer Loop:  2
#  Swapping Order of outer loop:  25  ,  18
#  Inner Loop:  2
#  Swapping order of inner loop:  18  ,  25
#  Inner Loop:  1
# Outer Loop:  3
# Sorted Array in Ascending Order:
# [16 18 21 25 29]

# %%
def insertionSort(arr):
 ctr=0
    for i in range(1, len(arr)):

        temp = arr[i]
        j = i - 1            
        for j in range(len(arr)-1):
          
          if arr[j + 1] < arr[j]:

             temp = arr[j]
             arr[j] = arr[j+1]
             arr[j+1] = temp

print(ctr)
data = [23, 5, 14, 76, 2]
print("Unsorted Array:\n" ,data)
insertionSort(data)
print("Sorted Array:\n" ,data)
# Out:
#   File "<ipython-input-3-6c98d1f64dfb>", line 3
#     for i in range(1, len(arr)):
#     ^
# IndentationError: unexpected indent
